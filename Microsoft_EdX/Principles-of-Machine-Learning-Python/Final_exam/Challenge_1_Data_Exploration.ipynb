# %% [markdown]
# To complete this challenge:
#
# 1. Download the Adventure Works data files - see previous unit.
# 2. Clean the data by replacing any missing values and removing duplicate rows. In this dataset, each customer is identified by a unique customer ID. The most recent version of a duplicated record should be retained.
# 3. Explore the data by calculating summary and descriptive statistics for the features in the dataset, calculating correlations between features, and creating data visualizations to determine apparent relationships in the data.
# 4. Based on your analysis of the customer data after removing all duplicate customer records, answer the questions below.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import numpy.random as nr
import math

# %% [markdown]
# # Data cleaning and basic statistics

# %% [markdown]
# ## Average month spending file

# %%
AveMonthSpend = pd.read_csv('AW_AveMonthSpend.csv')
AveMonthSpend.head(20)
# Out:
#     CustomerID  AveMonthSpend
# 0        11000             89
# 1        11001            117
# 2        11002            123
# 3        11003             50
# 4        11004             95
# 5        11005             78
# 6        11006             54
# 7        11007            130
# 8        11008             85
# 9        11009             74
# 10       11010             49
# 11       11011            146
# 12       11012             55
# 13       11013             84
# 14       11014             49
# 15       11015             39
# 16       11016             68
# 17       11019             64
# 18       11020             64
# 19       11023             71

# %% [markdown]
# We need to check if there are duplicate customers ID

# %%
print(AveMonthSpend.shape)
print(AveMonthSpend.CustomerID.unique().shape)
# Out:
# (16519, 2)
# (16404,)

# %% [markdown]
# Now we need to remove the duplicated rows.The most recent version of a duplicated record should be retained.
# the keep flag has two options: first and last.

# %%
AveMonthSpend.drop_duplicates(subset = 'CustomerID', keep = 'last', inplace = True)
print(AveMonthSpend.shape)
print(AveMonthSpend.CustomerID.unique().shape)
# Out:
# (16404, 2)
# (16404,)

# %% [markdown]
# Lets get a statistical summary of the data, notice that the median is the 50% percentil

# %%
AveMonthSpend.describe()
# Out:
#          CustomerID  AveMonthSpend
# count  16404.000000   16404.000000
# mean   20240.143136      72.391002
# std     5340.370705      27.269921
# min    11000.000000      22.000000
# 25%    15617.750000      52.000000
# 50%    20231.500000      68.000000
# 75%    24862.250000      84.000000
# max    29482.000000     176.000000

# %%
AveMonthSpend.median()
# Out:
# CustomerID       20231.5
# AveMonthSpend       68.0
# dtype: float64

# %% [markdown]
# ## Bike Buyer file

# %%
BikeBuyer = pd.read_csv('AW_BikeBuyer.csv')
BikeBuyer.head(20)
# Out:
#     CustomerID  BikeBuyer
# 0        11000          0
# 1        11001          1
# 2        11002          0
# 3        11003          0
# 4        11004          1
# 5        11005          1
# 6        11006          1
# 7        11007          1
# 8        11008          1
# 9        11009          0
# 10       11010          0
# 11       11011          1
# 12       11012          1
# 13       11013          0
# 14       11014          0
# 15       11015          0
# 16       11016          0
# 17       11019          1
# 18       11020          0
# 19       11023          0

# %%
print(BikeBuyer.shape)
print(BikeBuyer.CustomerID.unique().shape)b
# Out:
# (16519, 2)
# (16404,)

# %%
BikeBuyer.drop_duplicates(subset = 'CustomerID', keep = 'last', inplace = True)
print(BikeBuyer.shape)
print(BikeBuyer.CustomerID.unique().shape)
# Out:
# (16404, 2)
# (16404,)

# %% [markdown]
# ## Customers demographic file

# %%
Demographics = pd.read_csv('AdvWorksCusts.csv')
Demographics.head(20) # TBH here is better to open the data or r
# Out:
#     CustomerID Title  FirstName MiddleName LastName Suffix  \
# 0        11000   NaN        Jon          V     Yang    NaN
# 1        11001   NaN     Eugene          L    Huang    NaN
# 2        11002   NaN      Ruben        NaN   Torres    NaN
# 3        11003   NaN    Christy        NaN      Zhu    NaN
# 4        11004   NaN  Elizabeth        NaN  Johnson    NaN
# 5        11005   NaN      Julio        NaN     Ruiz    NaN
# 6        11006   NaN      Janet          G  Alvarez    NaN
# 7        11007   NaN      Marco        NaN    Mehta    NaN
# 8        11008   NaN        Rob        NaN  Verhoff    NaN
# 9        11009   NaN    Shannon          C  Carlson    NaN
# 10       11010   NaN  Jacquelyn          C   Suarez    NaN
# 11       11011   NaN     Curtis        NaN       Lu    NaN
# 12       11012   NaN     Lauren          M   Walker    NaN
# 13       11013   NaN        Ian          M  Jenkins    NaN
# 14       11014   NaN     Sydney        NaN  Bennett    NaN
# 15       11015   NaN      Chloe        NaN    Young    NaN
# 16       11016   NaN      Wyatt          L     Hill    NaN
# 17       11019   NaN       Luke          L      Lal    NaN
# 18       11020   NaN     Jordan          C     King    NaN
# 19       11023   NaN       Seth          M  Edwards    NaN
#
#             AddressLine1 AddressLine2            City StateProvinceName  ...  \
# 0        3761 N. 14th St          NaN     Rockhampton        Queensland  ...
# 1             2243 W St.          NaN         Seaford          Victoria  ...
# 2       5844 Linden Land          NaN          Hobart          Tasmania  ...
# 3       1825 Village Pl.          NaN      North Ryde   New South Wales  ...
# 4    7553 Harness Circle          NaN      Wollongong   New South Wales  ...
# 5    7305 Humphrey Drive          NaN   East Brisbane        Queensland  ...
# 6          2612 Berry Dr          NaN      Matraville   New South Wales  ...
# 7       942 Brook Street          NaN     Warrnambool          Victoria  ...
# 8       624 Peabody Road          NaN         Bendigo          Victoria  ...
# 9    3839 Northgate Road          NaN      Hervey Bay        Queensland  ...
# 10   7800 Corrinne Court          NaN   East Brisbane        Queensland  ...
# 11          1224 Shoenic          NaN   East Brisbane        Queensland  ...
# 12     4785 Scott Street          NaN       Bremerton        Washington  ...
# 13      7902 Hudson Ave.          NaN         Lebanon            Oregon  ...
# 14       9011 Tank Drive          NaN         Redmond        Washington  ...
# 15  244 Willow Pass Road          NaN         Burbank        California  ...
# 16   9666 Northridge Ct.          NaN  Imperial Beach        California  ...
# 17       7832 Landing Dr          NaN         Langley  British Columbia  ...
# 18         7156 Rose Dr.          NaN       Metchosin  British Columbia  ...
# 19     4499 Valley Crest          NaN      Bellflower        California  ...
#
#      BirthDate        Education      Occupation Gender MaritalStatus  \
# 0   1966-04-08       Bachelors     Professional      M             M
# 1   1965-05-14       Bachelors     Professional      M             S
# 2   1965-08-12       Bachelors     Professional      M             M
# 3   1968-02-15       Bachelors     Professional      F             S
# 4   1968-08-08       Bachelors     Professional      F             S
# 5   1965-08-05       Bachelors     Professional      M             S
# 6   1965-12-06       Bachelors     Professional      F             S
# 7   1964-05-09       Bachelors     Professional      M             M
# 8   1964-07-07       Bachelors     Professional      F             S
# 9   1964-04-01       Bachelors     Professional      M             S
# 10  1964-02-06       Bachelors     Professional      F             S
# 11  1963-11-04       Bachelors     Professional      M             M
# 12  1968-01-18       Bachelors       Management      F             M
# 13  1968-08-06       Bachelors       Management      M             M
# 14  1968-05-09       Bachelors       Management      F             S
# 15  1979-02-27  Partial College  Skilled Manual      F             S
# 16  1979-04-28  Partial College  Skilled Manual      M             M
# 17  1978-03-07      High School  Skilled Manual      M             S
# 18  1978-09-20      High School  Skilled Manual      M             S
# 19  1978-10-11  Partial College  Skilled Manual      M             M
#
#    HomeOwnerFlag NumberCarsOwned NumberChildrenAtHome  TotalChildren  \
# 0              1               0                    0              2
# 1              0               1                    3              3
# 2              1               1                    3              3
# 3              0               1                    0              0
# 4              1               4                    5              5
# 5              1               1                    0              0
# 6              1               1                    0              0
# 7              1               2                    3              3
# 8              1               3                    4              4
# 9              0               1                    0              0
# 10             0               1                    0              0
# 11             1               4                    4              4
# 12             1               2                    0              2
# 13             1               3                    0              2
# 14             0               3                    0              3
# 15             0               1                    0              0
# 16             1               1                    0              0
# 17             0               2                    0              0
# 18             0               2                    0              0
# 19             1               1                    0              0
#
#     YearlyIncome
# 0         137947
# 1         101141
# 2          91945
# 3          86688
# 4          92771
# 5         103199
# 6          84756
# 7         109759
# 8          88005
# 9         106399
# 10         81294
# 11         94029
# 12         99245
# 13        115859
# 14        105157
# 15         40011
# 16         46808
# 17         49455
# 18         43857
# 19         50046
#
# [20 rows x 23 columns]
