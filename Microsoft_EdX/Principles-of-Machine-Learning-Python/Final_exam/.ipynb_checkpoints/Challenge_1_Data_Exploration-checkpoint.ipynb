# %% [markdown]
# To complete this challenge:
#
# 1. Download the Adventure Works data files - see previous unit.
# 2. Clean the data by replacing any missing values and removing duplicate rows. In this dataset, each customer is identified by a unique customer ID. The most recent version of a duplicated record should be retained.
# 3. Explore the data by calculating summary and descriptive statistics for the features in the dataset, calculating correlations between features, and creating data visualizations to determine apparent relationships in the data.
# 4. Based on your analysis of the customer data after removing all duplicate customer records, answer the questions below.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import numpy.random as nr
import math

# %% [markdown]
# # Data cleaning and basic statistics

# %% [markdown]
# ## Average month spending file

# %%
AveMonthSpend = pd.read_csv('AW_AveMonthSpend.csv')
TestSet = pd.read_csv('AW_test.csv')
AveMonthSpend.head(20)
# Out:
#     CustomerID  AveMonthSpend
# 0        11000             89
# 1        11001            117
# 2        11002            123
# 3        11003             50
# 4        11004             95
# 5        11005             78
# 6        11006             54
# 7        11007            130
# 8        11008             85
# 9        11009             74
# 10       11010             49
# 11       11011            146
# 12       11012             55
# 13       11013             84
# 14       11014             49
# 15       11015             39
# 16       11016             68
# 17       11019             64
# 18       11020             64
# 19       11023             71

# %% [markdown]
# We need to check if there are duplicate customers ID

# %%
print(AveMonthSpend.shape)
print(AveMonthSpend.CustomerID.unique().shape)

# For the test set
print(TestSet.shape)
print(TestSet.CustomerID.unique().shape)
# Out:
# (16519, 2)
# (16404,)
# (500, 23)
# (500,)

# %% [markdown]
# **The test set does not have duplicates so I will use it as it is in the Challenge 2**

# %% [markdown]
# Now we need to remove the duplicated rows.The most recent version of a duplicated record should be retained.
# the keep flag has two options: first and last.

# %%
AveMonthSpend.drop_duplicates(subset = 'CustomerID', keep = 'last', inplace = True)
print(AveMonthSpend.shape)
print(AveMonthSpend.CustomerID.unique().shape)
# Out:
# (16404, 2)
# (16404,)

# %% [markdown]
# Lets get a statistical summary of the data, notice that the median is the 50% percentil

# %%
AveMonthSpend.describe()
# Out:
#          CustomerID  AveMonthSpend
# count  16404.000000   16404.000000
# mean   20240.143136      72.391002
# std     5340.370705      27.269921
# min    11000.000000      22.000000
# 25%    15617.750000      52.000000
# 50%    20231.500000      68.000000
# 75%    24862.250000      84.000000
# max    29482.000000     176.000000

# %%
AveMonthSpend.median()
# Out:
# CustomerID       20231.5
# AveMonthSpend       68.0
# dtype: float64

# %% [markdown]
# ## Bike Buyer file

# %%
BikeBuyer = pd.read_csv('AW_BikeBuyer.csv')
BikeBuyer.head(20)
# Out:
#     CustomerID  BikeBuyer
# 0        11000          0
# 1        11001          1
# 2        11002          0
# 3        11003          0
# 4        11004          1
# 5        11005          1
# 6        11006          1
# 7        11007          1
# 8        11008          1
# 9        11009          0
# 10       11010          0
# 11       11011          1
# 12       11012          1
# 13       11013          0
# 14       11014          0
# 15       11015          0
# 16       11016          0
# 17       11019          1
# 18       11020          0
# 19       11023          0

# %%
print(BikeBuyer.shape)
print(BikeBuyer.CustomerID.unique().shape)
# Out:
# (16519, 2)
# (16404,)

# %%
BikeBuyer.drop_duplicates(subset = 'CustomerID', keep = 'last', inplace = True)
print(BikeBuyer.shape)
print(BikeBuyer.CustomerID.unique().shape)
# Out:
# (16404, 2)
# (16404,)

# %% [markdown]
# ## Customers demographic file

# %%
Demographics = pd.read_csv('AdvWorksCusts.csv')
Demographics.head(10) # TBH here is better to open the data or use spyder
# Out:
#    CustomerID Title  FirstName MiddleName LastName Suffix  \
# 0       11000   NaN        Jon          V     Yang    NaN
# 1       11001   NaN     Eugene          L    Huang    NaN
# 2       11002   NaN      Ruben        NaN   Torres    NaN
# 3       11003   NaN    Christy        NaN      Zhu    NaN
# 4       11004   NaN  Elizabeth        NaN  Johnson    NaN
# 5       11005   NaN      Julio        NaN     Ruiz    NaN
# 6       11006   NaN      Janet          G  Alvarez    NaN
# 7       11007   NaN      Marco        NaN    Mehta    NaN
# 8       11008   NaN        Rob        NaN  Verhoff    NaN
# 9       11009   NaN    Shannon          C  Carlson    NaN
#
#           AddressLine1 AddressLine2           City StateProvinceName  ...  \
# 0      3761 N. 14th St          NaN    Rockhampton        Queensland  ...
# 1           2243 W St.          NaN        Seaford          Victoria  ...
# 2     5844 Linden Land          NaN         Hobart          Tasmania  ...
# 3     1825 Village Pl.          NaN     North Ryde   New South Wales  ...
# 4  7553 Harness Circle          NaN     Wollongong   New South Wales  ...
# 5  7305 Humphrey Drive          NaN  East Brisbane        Queensland  ...
# 6        2612 Berry Dr          NaN     Matraville   New South Wales  ...
# 7     942 Brook Street          NaN    Warrnambool          Victoria  ...
# 8     624 Peabody Road          NaN        Bendigo          Victoria  ...
# 9  3839 Northgate Road          NaN     Hervey Bay        Queensland  ...
#
#     BirthDate   Education    Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0  1966-04-08  Bachelors   Professional      M             M             1
# 1  1965-05-14  Bachelors   Professional      M             S             0
# 2  1965-08-12  Bachelors   Professional      M             M             1
# 3  1968-02-15  Bachelors   Professional      F             S             0
# 4  1968-08-08  Bachelors   Professional      F             S             1
# 5  1965-08-05  Bachelors   Professional      M             S             1
# 6  1965-12-06  Bachelors   Professional      F             S             1
# 7  1964-05-09  Bachelors   Professional      M             M             1
# 8  1964-07-07  Bachelors   Professional      F             S             1
# 9  1964-04-01  Bachelors   Professional      M             S             0
#
#   NumberCarsOwned NumberChildrenAtHome  TotalChildren  YearlyIncome
# 0               0                    0              2        137947
# 1               1                    3              3        101141
# 2               1                    3              3         91945
# 3               1                    0              0         86688
# 4               4                    5              5         92771
# 5               1                    0              0        103199
# 6               1                    0              0         84756
# 7               2                    3              3        109759
# 8               3                    4              4         88005
# 9               1                    0              0        106399
#
# [10 rows x 23 columns]

# %% [markdown]
# ## Question 6
# The distribution of the values in the BikeBuyer column indicates?
# To solve this, we just build a histogram.

# %%
BikeBuyer['BikeBuyer'].value_counts()
# Out:
# 0    10949
# 1     5455
# Name: BikeBuyer, dtype: int64

# %%
def hist_plot(vals, lab):
    ## Distribution plot of values
    sns.distplot(vals)
    plt.title('Histogram of ' + lab)
    plt.xlabel('Value')
    plt.ylabel('Density')
    
hist_plot(BikeBuyer['BikeBuyer'],'BikeBuyers')

# %% [markdown]
# ## Question 7
# Select the correct order (from lowest to highest) that ranks the median YearlyIncome by Occupation

# %%
def plot_box(data, col, col_y = 'price'):
    """
    data is a pandas dataframe
    col is the column with the categorical values
    col_y is the column with the quantitative values
    """
    sns.set_style("whitegrid")
    sns.boxplot(col, col_y, data = data)
    plt.xlabel(col) # Set text for the x axis
    plt.ylabel(col_y)# Set text for y axis
    plt.show()
    
plot_box(Demographics, "Occupation",
        "YearlyIncome")

# %% [markdown]
# ## Question 8
# Based on their age at the time when the data was collected (1st January 1998),which group of customers accounts for the highest AveMonthSpend values
#
# In order, to solve this, we need see the datatypes first

# %%
Demographics.dtypes
# Out:
# CustomerID               int64
# Title                   object
# FirstName               object
# MiddleName              object
# LastName                object
# Suffix                  object
# AddressLine1            object
# AddressLine2            object
# City                    object
# StateProvinceName       object
# CountryRegionName       object
# PostalCode              object
# PhoneNumber             object
# BirthDate               object
# Education               object
# Occupation              object
# Gender                  object
# MaritalStatus           object
# HomeOwnerFlag            int64
# NumberCarsOwned          int64
# NumberChildrenAtHome     int64
# TotalChildren            int64
# YearlyIncome             int64
# dtype: object

# %%
TestSet.dtypes
# Out:
# CustomerID               int64
# Title                   object
# FirstName               object
# MiddleName              object
# LastName                object
# Suffix                  object
# AddressLine1            object
# AddressLine2            object
# City                    object
# StateProvinceName       object
# CountryRegionName       object
# PostalCode              object
# PhoneNumber             object
# BirthDate               object
# Education               object
# Occupation              object
# Gender                  object
# MaritalStatus           object
# HomeOwnerFlag            int64
# NumberCarsOwned          int64
# NumberChildrenAtHome     int64
# TotalChildren            int64
# YearlyIncome             int64
# dtype: object

# %% [markdown]
# So we need to transform from object to dates and then substract the dates and convert to years

# %%
# Operating on the training set
birthdates = pd.to_datetime(Demographics['BirthDate'])
ages = (pd.to_datetime('1998-01-01')-birthdates)/np.timedelta64(1, 'Y')
Demographics["Ages"] = ages # Adding the new column


# Operating on the test set
test_birthdates = pd.to_datetime(TestSet['BirthDate'])
test_ages = (pd.to_datetime('1998-01-01')-test_birthdates)/np.timedelta64(1, 'Y')
TestSet["Ages"] = test_ages # Adding the new column

# %% [markdown]
# Now we need to classify in 4 groups of ages [<25 = group 1, [25,45] group 2, [45,55] group 3, >55 group 4

# %%
# This is just to take an array with the ages and operate in numpy
age_group = ages.values

indexes_g1 = np.where(ages<25)[0]
indexes_g2 = np.where((ages>25)&(ages<45))[0]
indexes_g3 = np.where((ages>45)&(ages<55))[0]
indexes_g4 = np.where(ages>55)[0]


ages[indexes_g1] = "Group_1"
ages[indexes_g2] = "Group_2"
ages[indexes_g3] = "Group_3"
ages[indexes_g4] = "Group_4"

Demographics["AgeGroup"] = ages
Demographics["AveMonthSpend"] = AveMonthSpend['AveMonthSpend']


# For the test set

test_age_group = test_ages.values

indexes_g1 = np.where(test_ages<25)[0]
indexes_g2 = np.where((test_ages>25)&(test_ages<45))[0]
indexes_g3 = np.where((test_ages>45)&(test_ages<55))[0]
indexes_g4 = np.where(test_ages>55)[0]


test_ages[indexes_g1] = "Group_1"
test_ages[indexes_g2] = "Group_2"
test_ages[indexes_g3] = "Group_3"
test_ages[indexes_g4] = "Group_4"

TestSet["AgeGroup"] = test_ages

# %%
Demographics.head(10)
# Out:
#    CustomerID Title  FirstName MiddleName LastName Suffix  \
# 0       11000   NaN        Jon          V     Yang    NaN
# 1       11001   NaN     Eugene          L    Huang    NaN
# 2       11002   NaN      Ruben        NaN   Torres    NaN
# 3       11003   NaN    Christy        NaN      Zhu    NaN
# 4       11004   NaN  Elizabeth        NaN  Johnson    NaN
# 5       11005   NaN      Julio        NaN     Ruiz    NaN
# 6       11006   NaN      Janet          G  Alvarez    NaN
# 7       11007   NaN      Marco        NaN    Mehta    NaN
# 8       11008   NaN        Rob        NaN  Verhoff    NaN
# 9       11009   NaN    Shannon          C  Carlson    NaN
#
#           AddressLine1 AddressLine2           City StateProvinceName  ...  \
# 0      3761 N. 14th St          NaN    Rockhampton        Queensland  ...
# 1           2243 W St.          NaN        Seaford          Victoria  ...
# 2     5844 Linden Land          NaN         Hobart          Tasmania  ...
# 3     1825 Village Pl.          NaN     North Ryde   New South Wales  ...
# 4  7553 Harness Circle          NaN     Wollongong   New South Wales  ...
# 5  7305 Humphrey Drive          NaN  East Brisbane        Queensland  ...
# 6        2612 Berry Dr          NaN     Matraville   New South Wales  ...
# 7     942 Brook Street          NaN    Warrnambool          Victoria  ...
# 8     624 Peabody Road          NaN        Bendigo          Victoria  ...
# 9  3839 Northgate Road          NaN     Hervey Bay        Queensland  ...
#
#   Gender MaritalStatus HomeOwnerFlag NumberCarsOwned NumberChildrenAtHome  \
# 0      M             M             1               0                    0
# 1      M             S             0               1                    3
# 2      M             M             1               1                    3
# 3      F             S             0               1                    0
# 4      F             S             1               4                    5
# 5      M             S             1               1                    0
# 6      F             S             1               1                    0
# 7      M             M             1               2                    3
# 8      F             S             1               3                    4
# 9      M             S             0               1                    0
#
#   TotalChildren YearlyIncome       Ages  AgeGroup  AveMonthSpend
# 0             2       137947  31.735080   Group_2           89.0
# 1             3       101141  32.635852   Group_2          117.0
# 2             3        91945  32.389440   Group_2          123.0
# 3             0        86688  29.878779   Group_2           50.0
# 4             5        92771  29.399645   Group_2           95.0
# 5             0       103199  32.408605   Group_2           78.0
# 6             0        84756  32.071843   Group_2           54.0
# 7             3       109759  33.648877   Group_2          130.0
# 8             4        88005  33.487341   Group_2           85.0
# 9             0       106399  33.752918   Group_2           74.0
#
# [10 rows x 26 columns]

# %%
TestSet.head(10)
# Out:
#    CustomerID Title  FirstName MiddleName   LastName Suffix  \
# 0       18988   NaN   Courtney          A      Baker    NaN
# 1       29135   NaN       Adam          C      Allen    NaN
# 2       12156   NaN     Bonnie        NaN       Raji    NaN
# 3       13749   NaN      Julio          C     Alonso    NaN
# 4       27780   NaN    Christy          A   Andersen    NaN
# 5       16375   NaN  Gabriella        NaN  Hernandez    NaN
# 6       16109   NaN       Adam          K     Turner    NaN
# 7       15606   NaN      Marco          C     Prasad    NaN
# 8       20888   NaN    Clayton          P       Raje    NaN
# 9       20716   NaN   Kristina          V       Arun    NaN
#
#                AddressLine1 AddressLine2                City  \
# 0     8727 Buena Vista Ave.          NaN             Fremont
# 1          3491 Cook Street          NaN               Haney
# 2      359 Pleasant Hill Rd          NaN             Burbank
# 3          8945 Euclid Ave.          NaN          Burlingame
# 4    42, boulevard Tremblay          NaN           Dunkerque
# 5    5689 Almondtree Circle          NaN       Spring Valley
# 6  9800 American Beauty Dr.          NaN        N. Vancouver
# 7           8523 Rose Drive            C          Cranbourne
# 8        4, place du Tertre          NaN  Tremblay-en-France
# 9                Waldstr 29          NaN            Hannover
#
#      StateProvinceName  ...      Occupation Gender MaritalStatus  \
# 0           California  ...      Management      F             S
# 1     British Columbia  ...  Skilled Manual      M             M
# 2           California  ...      Management      F             M
# 3           California  ...  Skilled Manual      M             M
# 4                 Nord  ...          Manual      F             M
# 5           California  ...        Clerical      F             M
# 6     British Columbia  ...  Skilled Manual      M             S
# 7             Victoria  ...    Professional      M             M
# 8    Seine Saint Denis  ...          Manual      M             S
# 9  Nordrhein-Westfalen  ...  Skilled Manual      F             M
#
#   HomeOwnerFlag NumberCarsOwned NumberChildrenAtHome TotalChildren  \
# 0             0               2                    0             5
# 1             1               2                    2             4
# 2             1               2                    0             4
# 3             1               0                    0             4
# 4             1               1                    2             2
# 5             1               1                    0             1
# 6             1               2                    2             4
# 7             1               3                    4             4
# 8             1               1                    4             4
# 9             1               1                    1             1
#
#   YearlyIncome       Ages  AgeGroup
# 0        86931  52.989452   Group_3
# 1       100125  33.243667   Group_2
# 2       103985  63.971197   Group_4
# 3       127161  39.278014   Group_2
# 4        21876  32.789174   Group_2
# 5        44467  40.359487   Group_2
# 6        77702  33.492816   Group_2
# 7        99418  33.057489   Group_2
# 8        13522  31.945899   Group_2
# 9        46264  24.301663   Group_1
#
# [10 rows x 25 columns]

# %%
ax = sns.boxplot(x="AgeGroup", y="AveMonthSpend", hue="Gender",
                 data = Demographics)

# %% [markdown]
# ## Question  9
# For the questions, the only categories tha need to be organised are:
# 1. Car number divide in 3 groups (No cars, 1-2, 3 or more)
# 2. Children ( yes or no)

# %% [markdown]
# ## Grouping the number of cars

# %%
# Dealing with the number of cars

def group_cars(df):
    number_of_cars = df["NumberCarsOwned"].copy()

    indexes_g1 = np.where(number_of_cars ==0)[0]
    indexes_g2 = np.where((number_of_cars>0)&(number_of_cars<3))[0]
    indexes_g3 = np.where(number_of_cars>=3)[0]


    number_of_cars[indexes_g1] = "No_car"
    number_of_cars[indexes_g2] = "1-2"
    number_of_cars[indexes_g3] = "3 or more"
    
    return number_of_cars


Demographics["CarGroup"] = group_cars(Demographics)

TestSet["CarGroup"] = group_cars(TestSet)

# %% [markdown]
# ## Grouping the number of Children

# %%
# Dealing with the number of children


def group_children(df):
    number_of_children = df["NumberChildrenAtHome"].copy()


    indexes_g1 = np.where(number_of_children ==0)[0]
    indexes_g2 = np.where(number_of_children>=1)[0]


    number_of_children[indexes_g1] = "No_children"
    number_of_children[indexes_g2] = "With_Children"
    
    return number_of_children

Demographics["Children"] = group_children(Demographics)

TestSet["Children"] = group_children(TestSet)

Demographics.head(10)
# Out:
#    CustomerID Title  FirstName MiddleName LastName Suffix  \
# 0       11000   NaN        Jon          V     Yang    NaN
# 1       11001   NaN     Eugene          L    Huang    NaN
# 2       11002   NaN      Ruben        NaN   Torres    NaN
# 3       11003   NaN    Christy        NaN      Zhu    NaN
# 4       11004   NaN  Elizabeth        NaN  Johnson    NaN
# 5       11005   NaN      Julio        NaN     Ruiz    NaN
# 6       11006   NaN      Janet          G  Alvarez    NaN
# 7       11007   NaN      Marco        NaN    Mehta    NaN
# 8       11008   NaN        Rob        NaN  Verhoff    NaN
# 9       11009   NaN    Shannon          C  Carlson    NaN
#
#           AddressLine1 AddressLine2           City StateProvinceName  ...  \
# 0      3761 N. 14th St          NaN    Rockhampton        Queensland  ...
# 1           2243 W St.          NaN        Seaford          Victoria  ...
# 2     5844 Linden Land          NaN         Hobart          Tasmania  ...
# 3     1825 Village Pl.          NaN     North Ryde   New South Wales  ...
# 4  7553 Harness Circle          NaN     Wollongong   New South Wales  ...
# 5  7305 Humphrey Drive          NaN  East Brisbane        Queensland  ...
# 6        2612 Berry Dr          NaN     Matraville   New South Wales  ...
# 7     942 Brook Street          NaN    Warrnambool          Victoria  ...
# 8     624 Peabody Road          NaN        Bendigo          Victoria  ...
# 9  3839 Northgate Road          NaN     Hervey Bay        Queensland  ...
#
#   HomeOwnerFlag NumberCarsOwned NumberChildrenAtHome TotalChildren  \
# 0             1               0                    0             2
# 1             0               1                    3             3
# 2             1               1                    3             3
# 3             0               1                    0             0
# 4             1               4                    5             5
# 5             1               1                    0             0
# 6             1               1                    0             0
# 7             1               2                    3             3
# 8             1               3                    4             4
# 9             0               1                    0             0
#
#   YearlyIncome       Ages AgeGroup AveMonthSpend   CarGroup       Children
# 0       137947  31.735080  Group_2          89.0     No_car    No_children
# 1       101141  32.635852  Group_2         117.0        1-2  With_Children
# 2        91945  32.389440  Group_2         123.0        1-2  With_Children
# 3        86688  29.878779  Group_2          50.0        1-2    No_children
# 4        92771  29.399645  Group_2          95.0  3 or more  With_Children
# 5       103199  32.408605  Group_2          78.0        1-2    No_children
# 6        84756  32.071843  Group_2          54.0        1-2    No_children
# 7       109759  33.648877  Group_2         130.0        1-2  With_Children
# 8        88005  33.487341  Group_2          85.0  3 or more  With_Children
# 9       106399  33.752918  Group_2          74.0        1-2    No_children
#
# [10 rows x 28 columns]

# %%
TestSet.head(10)
# Out:
#    CustomerID Title  FirstName MiddleName   LastName Suffix  \
# 0       18988   NaN   Courtney          A      Baker    NaN
# 1       29135   NaN       Adam          C      Allen    NaN
# 2       12156   NaN     Bonnie        NaN       Raji    NaN
# 3       13749   NaN      Julio          C     Alonso    NaN
# 4       27780   NaN    Christy          A   Andersen    NaN
# 5       16375   NaN  Gabriella        NaN  Hernandez    NaN
# 6       16109   NaN       Adam          K     Turner    NaN
# 7       15606   NaN      Marco          C     Prasad    NaN
# 8       20888   NaN    Clayton          P       Raje    NaN
# 9       20716   NaN   Kristina          V       Arun    NaN
#
#                AddressLine1 AddressLine2                City  \
# 0     8727 Buena Vista Ave.          NaN             Fremont
# 1          3491 Cook Street          NaN               Haney
# 2      359 Pleasant Hill Rd          NaN             Burbank
# 3          8945 Euclid Ave.          NaN          Burlingame
# 4    42, boulevard Tremblay          NaN           Dunkerque
# 5    5689 Almondtree Circle          NaN       Spring Valley
# 6  9800 American Beauty Dr.          NaN        N. Vancouver
# 7           8523 Rose Drive            C          Cranbourne
# 8        4, place du Tertre          NaN  Tremblay-en-France
# 9                Waldstr 29          NaN            Hannover
#
#      StateProvinceName  ... MaritalStatus HomeOwnerFlag NumberCarsOwned  \
# 0           California  ...             S             0               2
# 1     British Columbia  ...             M             1               2
# 2           California  ...             M             1               2
# 3           California  ...             M             1               0
# 4                 Nord  ...             M             1               1
# 5           California  ...             M             1               1
# 6     British Columbia  ...             S             1               2
# 7             Victoria  ...             M             1               3
# 8    Seine Saint Denis  ...             S             1               1
# 9  Nordrhein-Westfalen  ...             M             1               1
#
#   NumberChildrenAtHome TotalChildren YearlyIncome       Ages AgeGroup  \
# 0                    0             5        86931  52.989452  Group_3
# 1                    2             4       100125  33.243667  Group_2
# 2                    0             4       103985  63.971197  Group_4
# 3                    0             4       127161  39.278014  Group_2
# 4                    2             2        21876  32.789174  Group_2
# 5                    0             1        44467  40.359487  Group_2
# 6                    2             4        77702  33.492816  Group_2
# 7                    4             4        99418  33.057489  Group_2
# 8                    4             4        13522  31.945899  Group_2
# 9                    1             1        46264  24.301663  Group_1
#
#     CarGroup       Children
# 0        1-2    No_children
# 1        1-2  With_Children
# 2        1-2    No_children
# 3     No_car    No_children
# 4        1-2  With_Children
# 5        1-2    No_children
# 6        1-2  With_Children
# 7  3 or more  With_Children
# 8        1-2  With_Children
# 9        1-2  With_Children
#
# [10 rows x 27 columns]

# %%
print(TestSet.shape)
print(Demographics.shape)
# Out:
# (500, 27)
# (16519, 28)

# %% [markdown]
# The additional column in demographics are the AveMonthSpend

# %%
cols = ['MaritalStatus','CarGroup', 'Gender', 'Children']
def plot_violin(data, cols, col_y):
    for col in cols:
        sns.set_style("whitegrid")
        sns.violinplot(col, col_y, data = data)
        plt.xlabel(col) # Set text for the x axis
        plt.ylabel(col_y)# Set text for y axis
        plt.show()

plot_violin(Demographics, cols, "AveMonthSpend")

# %% [markdown]
# ## Question 1
# -The median YearlyIncome is higher for customers who bought a bike than for customers who didn't.
# -The median number of cars owned by customers who bought a bike is lower than for customers who didn't.
# -The most common occupation type for customers who bought a bike is skilled manual.
# -Male customers are more likely to buy bikes than female customers.
# -A maried customer is more likely to buy a bike.
#
#  For the first 2, we can make a plot, for the last 3 is just easier to do

# %%
# First adding the BikeBuyer
Demographics['Bikebuyer'] = BikeBuyer['BikeBuyer']

# %%
sns.violinplot('Bikebuyer', "YearlyIncome", data = Demographics)

# %%
sns.violinplot('Bikebuyer', "NumberCarsOwned", data = Demographics)

# %% [markdown]
# Determining a subset only for the buyers

# %%
is_buyer = Demographics['Bikebuyer'] == 1

Demographics_buyers = Demographics[is_buyer]
Demographics_buyers.shape
# Out:
# (5455, 29)

# %%
Demographics_buyers.head(10)
# Out:
#     CustomerID Title  FirstName MiddleName LastName Suffix  \
# 1        11001   NaN     Eugene          L    Huang    NaN
# 4        11004   NaN  Elizabeth        NaN  Johnson    NaN
# 5        11005   NaN      Julio        NaN     Ruiz    NaN
# 6        11006   NaN      Janet          G  Alvarez    NaN
# 7        11007   NaN      Marco        NaN    Mehta    NaN
# 8        11008   NaN        Rob        NaN  Verhoff    NaN
# 11       11011   NaN     Curtis        NaN       Lu    NaN
# 12       11012   NaN     Lauren          M   Walker    NaN
# 17       11019   NaN       Luke          L      Lal    NaN
# 41       11049   NaN      Carol          C      Rai    NaN
#
#            AddressLine1 AddressLine2           City StateProvinceName  ...  \
# 1            2243 W St.          NaN        Seaford          Victoria  ...
# 4   7553 Harness Circle          NaN     Wollongong   New South Wales  ...
# 5   7305 Humphrey Drive          NaN  East Brisbane        Queensland  ...
# 6         2612 Berry Dr          NaN     Matraville   New South Wales  ...
# 7      942 Brook Street          NaN    Warrnambool          Victoria  ...
# 8      624 Peabody Road          NaN        Bendigo          Victoria  ...
# 11         1224 Shoenic          NaN  East Brisbane        Queensland  ...
# 12    4785 Scott Street          NaN      Bremerton        Washington  ...
# 17      7832 Landing Dr          NaN        Langley  British Columbia  ...
# 41          6064 Madrid          NaN    Chula Vista        California  ...
#
#    NumberCarsOwned NumberChildrenAtHome TotalChildren YearlyIncome       Ages  \
# 1                1                    3             3       101141  32.635852
# 4                4                    5             5        92771  29.399645
# 5                1                    0             0       103199  32.408605
# 6                1                    0             0        84756  32.071843
# 7                2                    3             3       109759  33.648877
# 8                3                    4             4        88005  33.487341
# 11               4                    4             4        94029  34.160866
# 12               2                    0             2        99245  29.955441
# 17               2                    0             0        49455  19.822447
# 41               2                    0             0        48422  17.456895
#
#    AgeGroup AveMonthSpend   CarGroup       Children  Bikebuyer
# 1   Group_2         117.0        1-2  With_Children        1.0
# 4   Group_2          95.0  3 or more  With_Children        1.0
# 5   Group_2          78.0        1-2    No_children        1.0
# 6   Group_2          54.0        1-2    No_children        1.0
# 7   Group_2         130.0        1-2  With_Children        1.0
# 8   Group_2          85.0  3 or more  With_Children        1.0
# 11  Group_2         146.0  3 or more  With_Children        1.0
# 12  Group_2          55.0        1-2    No_children        1.0
# 17  Group_1          64.0        1-2    No_children        1.0
# 41  Group_1          41.0        1-2    No_children        1.0
#
# [10 rows x 29 columns]

# %%
Demographics_buyers['Occupation'].value_counts()
# Out:
# Professional      2184
# Skilled Manual    1135
# Management        1016
# Clerical           616
# Manual             504
# Name: Occupation, dtype: int64

# %%
Demographics_buyers['Gender'].value_counts()
# Out:
# M    3222
# F    2233
# Name: Gender, dtype: int64

# %%
Demographics['Gender'].value_counts()
# Out:
# M    8351
# F    8168
# Name: Gender, dtype: int64

# %%
Demographics_buyers['MaritalStatus'].value_counts()
# Out:
# S    3256
# M    2199
# Name: MaritalStatus, dtype: int64

# %%
Demographics['MaritalStatus'].value_counts()
# Out:
# M    8917
# S    7602
# Name: MaritalStatus, dtype: int64

# %%
# Exporting the data
Demographics.to_csv('Demographics.csv', index = False, header = True)
TestSet.to_csv("TestSet.csv",index = False, header = True )
